# %% [markdown]
# # Introduction
# In this notebook, we will walk through the steps to set up your first slack agent, this agent can be used to chat with users in direct messages.
#
# Follow the following steps to build and run the slack agent:
# 1. Create a slack app and get the slack token
# 2. Build the slack agent
# 3. Run the slack agent

# %% [markdown]
# ## Create Slack App

# %% [markdown]
# Follow the instructions [here](https://tools.slack.dev/bolt-python/getting-started) to setup the slack app and get the bot token and app token.
# We suggest you create a new slack workspace for testing your agent.
#
# ## Build the Slack Agent
